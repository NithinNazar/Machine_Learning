# %%
import pandas as pd

# %%
import numpy as np

# %%
my_index = ["Golf R", "GR Corolla", "A 45S AMG"]

# %%
my_data = [310,300,421]

# %%
my_ser = pd.Series(data=my_data)

# %%
my_ser
# Out:
# 0    310
# 1    300
# 2    421
# dtype: int64

# %%
my_ser = pd.Series(data=my_data, index=my_index)

# %%
my_ser
# Out:
# Golf R        310
# GR Corolla    300
# A 45S AMG     421
# dtype: int64

# %%
my_ser[0]
# Out:
# 310

# %%
my_ser["A 45S AMG"]
# Out:
# 421

# %%
my_dict = {"cpu cores":4, "cpu threads": 8, "ssd":512}

# %%
dict_ser = pd.Series(my_dict)

# %%
dict_ser
# Out:
# cpu cores        4
# cpu threads      8
# ssd            512
# dtype: int64

# %%
# Imaginary Sales Data for 1st and 2nd Quarters for Global Company
q1 = {'Japan': 80, 'China': 450, 'India': 200, 'USA': 250}
q2 = {'Brazil': 100,'China': 500, 'India': 210,'USA': 260}

# %%
sales_q1 = pd.Series(q1)

# %%
sales_q2 = pd.Series(q2)

# %%
sales_q1 + sales_q2
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
sales_q1[0]
# Out:
# 80

# %%
sales_q1["Japan"]  # ideal to use names index
# Out:
# 80

# %%
sales_q1.add(sales_q2, fill_value=0)
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64

# %%
sales_q2 /100
# Out:
# Brazil    1.0
# China     5.0
# India     2.1
# USA       2.6
# dtype: float64

# %%
pwd
# Out:
# 'C:\\Users\\NithinNazar\\Machine Learning\\ML JP'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is CE09-0150
#
#  Directory of C:\Users\NithinNazar\Machine Learning\ML JP
#
# 10/04/2022  12:17 AM    <DIR>          .
# 08/21/2022  11:34 PM    <DIR>          ..
# 09/30/2022  05:59 PM    <DIR>          .ipynb_checkpoints
# 06/16/2022  08:26 PM             9,718 NumPy_basics.ipynb
# 06/17/2022  02:38 PM            20,367 NumPy_basics-checkpoint.ipynb
# 07/02/2022  05:37 PM            23,127 numpy2.ipynb
# 10/04/2022  12:17 AM           131,390 Pandas practice.ipynb
# 07/08/2022  11:57 PM             3,151 pandas_basics.ipynb
# 06/17/2022  10:46 PM                72 Untitled.ipynb
# 07/08/2022  11:43 PM                72 Untitled1.ipynb
# 08/17/2022  12:19 AM            10,224 Untitled2.ipynb
#                8 File(s)        198,121 bytes
#                3 Dir(s)  294,248,144,896 bytes free

# %%
df = pd.read_csv("C:\\Users\\NithinNazar\\Machine Learning\\UNZIP-FOR-NOTEBOOKS-Ver7\\DATA\\tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
(df["total_bill"] > 30) & (df["sex"]=="Male")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
df[(df["total_bill"] > 30) & (df["sex"]=="Male")]
# Out:
#      total_bill    tip   sex smoker   day    time  size  price_per_person  \
# 23        39.42   7.58  Male     No   Sat  Dinner     4              9.86
# 39        31.27   5.00  Male     No   Sat  Dinner     3             10.42
# 44        30.40   5.60  Male     No   Sun  Dinner     4              7.60
# 47        32.40   6.00  Male     No   Sun  Dinner     4              8.10
# 56        38.01   3.00  Male    Yes   Sat  Dinner     4              9.50
# 59        48.27   6.73  Male     No   Sat  Dinner     4             12.07
# 83        32.68   5.00  Male    Yes  Thur   Lunch     2             16.34
# 95        40.17   4.73  Male    Yes   Fri  Dinner     4             10.04
# 112       38.07   4.00  Male     No   Sun  Dinner     3             12.69
# 141       34.30   6.70  Male     No  Thur   Lunch     6              5.72
# 142       41.19   5.00  Male     No  Thur   Lunch     5              8.24
# 156       48.17   5.00  Male     No   Sun  Dinner     6              8.03
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
def last_four(num):
    return str(num)[-4:]

# %%
df["CC Number"][0]
# Out:
# 3560325168603410

# %%
last_four(3560325168603410)
# Out:
# '3410'

# %%
df["Last Four"] = df["CC Number"].apply(last_four)  #  broadcast a function across the column we select

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID Last Four
# 0  Christy Cunningham  3560325168603410    Sun2959      3410
# 1      Douglas Tucker  4478071379779230    Sun4608      9230
# 2      Travis Walters  6011812112971322    Sun4458      1322
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994
# 4        Tonya Carter  4832732618637221    Sun2251      7221

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID Last Four
# ...

# %%
weekends = ["Sun", "Sat"]

# %%
df["day"].isin(weekends)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 239     True
# 240     True
# 241     True
# 242     True
# 243    False
# Name: day, Length: 244, dtype: bool

# %%
df[df["day"].isin(weekends)]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID Last Four
# ...

# %%
df = df.drop("Last Four", axis=1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.iloc[27]
# Out:
# total_bill                   12.69
# tip                            2.0
# sex                           Male
# smoker                          No
# day                            Sat
# time                        Dinner
# size                             2
# price_per_person              6.34
# Payer Name          Patrick Barber
# CC Number           30155551880343
# Payment ID                  Sat394
# Name: 27, dtype: object

# %%
df = df.set_index("Payment ID")

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df.loc["Sun4458"]
# Out:
# total_bill                     21.01
# tip                              3.5
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person                 7.0
# Payer Name            Travis Walters
# CC Number           6011812112971322
# Name: Sun4458, dtype: object

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
# apply with lambda

def simple(num):
    return num*2

# %%
simple(3)
# Out:
# 6

# %%
lambda num: num * 2  # takes an argument: do this with it and return
# Out:
# <function __main__.<lambda>(num)>

# %%
df["total_bill"].apply(lambda bill:bill*3)
# Out:
# Payment ID
# Sun2959    50.97
# Sun4608    31.02
# Sun4458    63.03
# Sun5260    71.04
# Sun2251    73.77
#            ...
# Sat2657    87.09
# Sat1766    81.54
# Sat3880    68.01
# Sat17      53.46
# Thur672    56.34
# Name: total_bill, Length: 244, dtype: float64

# %% [markdown]
# ## apply in multiple columns

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
def quality(total_bill, tip):
    if tip / total_bill > 0.25:
        return "Generous"
    else:
        return "Normal"

# %%
quality(21.01,3.50)
# Out:
# 'Normal'

# %%
df["Tip Quality"] = df[["total_bill", "tip"]].apply(lambda df: quality(df["total_bill"], df["tip"]), axis=1)

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number Tip Quality
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410      Normal
# Sun4608                 3.45      Douglas Tucker  4478071379779230      Normal
# Sun4458                 7.00      Travis Walters  6011812112971322      Normal
# Sun5260                11.84    Nathaniel Harris  4676137647685994      Normal
# Sun2251                 6.15        Tonya Carter  4832732618637221      Normal

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number Tip Quality
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410      Normal
# Sun4608                 3.45      Douglas Tucker  4478071379779230      Normal
# Sun4458                 7.00      Travis Walters  6011812112971322      Normal
# Sun5260                11.84    Nathaniel Harris  4676137647685994      Normal
# Sun2251                 6.15        Tonya Carter  4832732618637221      Normal

# %%
df.drop("Tip Quality", axis =1)
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df["Tip Quality"] = np.vectorize(quality)(df["total_bill"], df["tip"])

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number Tip Quality
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410      Normal
# ...

# %%
df[df["Tip Quality"] == "Generous"]
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4474          10.29  2.60  Female     No   Sun  Dinner     2
# Sat3455           3.07  1.00  Female    Yes   Sat  Dinner     1
# Fri6963          16.32  4.30  Female    Yes   Fri  Dinner     2
# Sat2614          14.31  4.00  Female    Yes   Sat  Dinner     2
# Thur6321          7.51  2.00    Male     No  Thur   Lunch     2
# Sun9209           7.25  5.15    Male    Yes   Sun  Dinner     2
# Sun4598           9.60  4.00  Female    Yes   Sun  Dinner     2
# Sun6059          23.17  6.50    Male    Yes   Sun  Dinner     4
# Fri7511          13.42  3.48  Female    Yes   Fri   Lunch     2
# Sat2124          11.61  3.39    Male     No   Sat  Dinner     2
#
#             price_per_person         Payer Name         CC Number Tip Quality
# Payment ID
# Sun4474                 5.14     Jessica Ibarra     4999759463713    Generous
# Sat3455                 3.07      Tiffany Brock  4359488526995267    Generous
# ...

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.sort_values("tip", ascending=False)
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sat1954          50.81  10.00    Male    Yes   Sat  Dinner     3
# Sat4590          48.33   9.00    Male     No   Sat  Dinner     4
# Sat239           39.42   7.58    Male     No   Sat  Dinner     4
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Thur1025         34.30   6.70    Male     No  Thur   Lunch     6
# ...                ...    ...     ...    ...   ...     ...   ...
# Sun2959          16.99   1.01  Female     No   Sun  Dinner     2
# Sat5032          12.60   1.00    Male    Yes   Sat  Dinner     2
# Sat4801           7.25   1.00  Female     No   Sat  Dinner     1
# Sat3455           3.07   1.00  Female    Yes   Sat  Dinner     1
# Fri3780           5.75   1.00  Female    Yes   Fri  Dinner     2
#
#             price_per_person          Payer Name         CC Number Tip Quality
# Payment ID
# Sat1954                16.94       Gregory Clark  5473850968388236      Normal
# ...

# %%
df.sort_values(["tip", "size"])
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sat3455           3.07   1.00  Female    Yes   Sat  Dinner     1
# Sat4801           7.25   1.00  Female     No   Sat  Dinner     1
# Fri3780           5.75   1.00  Female    Yes   Fri  Dinner     2
# Sat5032          12.60   1.00    Male    Yes   Sat  Dinner     2
# Sun2959          16.99   1.01  Female     No   Sun  Dinner     2
# ...                ...    ...     ...    ...   ...     ...   ...
# Thur1025         34.30   6.70    Male     No  Thur   Lunch     6
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Sat239           39.42   7.58    Male     No   Sat  Dinner     4
# Sat4590          48.33   9.00    Male     No   Sat  Dinner     4
# Sat1954          50.81  10.00    Male    Yes   Sat  Dinner     3
#
#             price_per_person          Payer Name         CC Number Tip Quality
# Payment ID
# Sat3455                 3.07       Tiffany Brock  4359488526995267    Generous
# ...

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number Tip Quality
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410      Normal
# Sun4608                 3.45      Douglas Tucker  4478071379779230      Normal
# Sun4458                 7.00      Travis Walters  6011812112971322      Normal
# Sun5260                11.84    Nathaniel Harris  4676137647685994      Normal
# Sun2251                 6.15        Tonya Carter  4832732618637221      Normal

# %%
df.sort_values("size")
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sat3455           3.07  1.00  Female    Yes   Sat  Dinner     1
# Thur4909         10.07  1.83  Female     No  Thur   Lunch     1
# Fri6624           8.58  1.92    Male    Yes   Fri   Lunch     1
# Sat4801           7.25  1.00  Female     No   Sat  Dinner     1
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# ...                ...   ...     ...    ...   ...     ...   ...
# Sun9176          29.85  5.14  Female     No   Sun  Dinner     5
# Thur6179         27.05  5.00  Female     No  Thur   Lunch     6
# Sun7518          48.17  5.00    Male     No   Sun  Dinner     6
# Thur1025         34.30  6.70    Male     No  Thur   Lunch     6
# Thur3948         29.80  4.20  Female     No  Thur   Lunch     6
#
#             price_per_person          Payer Name         CC Number Tip Quality
# Payment ID
# Sat3455                 3.07       Tiffany Brock  4359488526995267    Generous
# ...

# %%
df.corr()  # varies from -1 to 1. 1 means perfectly corelated
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number Tip Quality
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410      Normal
# Sun4608                 3.45      Douglas Tucker  4478071379779230      Normal
# Sun4458                 7.00      Travis Walters  6011812112971322      Normal
# Sun5260                11.84    Nathaniel Harris  4676137647685994      Normal
# Sun2251                 6.15        Tonya Carter  4832732618637221      Normal

# %%
df["total_bill"].max() # returns max value in column
# Out:
# 50.81

# %%
df["total_bill"].idxmax()  # index of max value
# Out:
# 'Sat1954'

# %%
df["total_bill"].idxmin()
# Out:
# 'Sat3455'

# %%
df.reset_index()
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number Tip Quality
# 0                8.49  Christy Cunningham  3560325168603410      Normal
# ...

# %%
df = df["Tip Quality"].replace(to_replace="Normal", value="OK")

# %%
df.head()
# Out:
# Payment ID
# Sun2959    OK
# Sun4608    OK
# Sun4458    OK
# Sun5260    OK
# Sun2251    OK
# Name: Tip Quality, dtype: object

# %%
df.head()
# Out:
# Payment ID
# Sun2959    OK
# Sun4608    OK
# Sun4458    OK
# Sun5260    OK
# Sun2251    OK
# Name: Tip Quality, dtype: object

# %%
df = pd.read_csv("C:\\Users\\NithinNazar\\Machine Learning\\UNZIP-FOR-NOTEBOOKS-Ver7\\DATA\\tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df["sex"] = df["sex"].replace(to_replace=["Female", "Male"], value=["F","M"])

# %%
df.head()
# Out:
#    total_bill   tip sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01   F     No  Sun  Dinner     2              8.49
# 1       10.34  1.66   M     No  Sun  Dinner     3              3.45
# 2       21.01  3.50   M     No  Sun  Dinner     3              7.00
# 3       23.68  3.31   M     No  Sun  Dinner     2             11.84
# 4       24.59  3.61   F     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df["sex"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df["size"].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
df["day"].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df["day"].nunique()
# Out:
# 4

# %%
my_map = {"Dinner": "D", "Lunch": "L"}  # useful to replace  multiple items

# %%
df["time"].map(my_map)
# Out:
# 0      D
# 1      D
# 2      D
# 3      D
# 4      D
#       ..
# 239    D
# 240    D
# 241    D
# 242    D
# 243    D
# Name: time, Length: 244, dtype: object
